# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.__version__

# %%
df=pd.read_csv("BlackFriday.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].nunique()
# Out:
# 7

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].nunique()
# Out:
# 21

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].nunique()
# Out:
# 3

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].nunique()
# Out:
# 5

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].nunique()
# Out:
# 2

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].nunique()
# Out:
# 18

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Purchase'].sum()
# Out:
# 5017668378

# %%
for columns in df.columns:
    print(df[columns].nunique(),"\t:",columns)
# Out:
# 5891 	: User_ID
# 3623 	: Product_ID
# 2 	: Gender
# 7 	: Age
# 21 	: Occupation
# 3 	: City_Category
# 5 	: Stay_In_Current_City_Years
# 2 	: Marital_Status
# 18 	: Product_Category_1
# 17959 	: Purchase

# %%
data=pd.DataFrame({"Ratio" :[len(df[df['Gender']=='M']),len(df[df['Gender']=='F'])]},index=['Male','Female'])
data.plot.pie(y="Ratio",title="Ratio of Gender",autopct="%.1f%%",figsize=(6,6))
# Out:
# <Axes: title={'center': 'Ratio of Gender'}, ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot.pie(title='Ratio of Gender',figsize=(6,6),autopct='%.1f%%')
# Out:
# <Axes: title={'center': 'Ratio of Gender'}>

# %%
df.groupby('Gender')['Purchase'].mean().plot.pie(title='Ratio of Gender',figsize=(6,6),autopct='%.1f%%')
# Out:
# <Axes: title={'center': 'Ratio of Gender'}, ylabel='Purchase'>

# %%
df.groupby('Gender').size().plot.bar(title='Ratio of Gender',figsize=(6,6))
# Out:
# <Axes: title={'center': 'Ratio of Gender'}, xlabel='Gender'>

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind='pie',title='Purchasing by Gender',figsize=(6,6),autopct='%.1f%%')
# Out:
# <Axes: title={'center': 'Purchasing by Gender'}, ylabel='Purchase'>

# %%
df.groupby('Age').size().plot.bar(title='Purchase Distribution by Age',figsize=(12,6))
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
lst=[]
for i in df['Age'].unique():
   lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])


data=pd.DataFrame(lst, columns=['Age','Products'])

# %%
data.plot.bar(x='Age',figsize=(8,6),title='Purchasing product by Group Age')
# Out:
# <Axes: title={'center': 'Purchasing product by Group Age'}, xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].plot.bar(title='Ammount spend by Age',figsize=(12,6))
# Out:
# <Axes: title={'center': 'Ammount spend by Age'}, xlabel='Age'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Gender',hue='Age',data=df,palette='dark')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='Marital_Status',hue='Gender',data=df,palette='dark')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df['Gender']=df['Gender'].astype(str)
df['Marital_Status']=df['Marital_Status'].astype(str)

sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='Gender',hue='Marital_Status',data=df,palette='dark')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(10,6)})
sns.countplot(x='City_Category',hue='Age',data=df,palette='dark')
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(10,6)})
sns.countplot(x='Age',hue='City_Category',data=df,palette='dark')

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct="%0.1f%%")

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender',data=df)

# %%
# Convert columns to strings
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype(str)
df['Marital_Status'] = df['Marital_Status'].astype(str)

# Now plot again
#sns.countplot(x='Stay_In_Current_City_Years', hue='Marital_Status', data=df)
plt.show()


sns.countplot(x='Stay_In_Current_City_Years',hue='Marital_Status',data=df)

# %%
sns.set(rc={'figure.figsize':(10, 6)})
sns.countplot(x='Stay_In_Current_City_Years',hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(10, 6)})
sns.countplot(x='City_Category',hue='Age',data=df,palette='rocket')

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct="%0.1f%%",figsize=(6,6),colors=['#CD5C5C','#F08080','#E9967A','#FFA07A','#6495ED'])

# %%
df.columns

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct='%0.1f%%',title='Purchase by City Category',figsize=(6,6),colors=['#ffcc99','#99ff99','#66b3ff'],startangle=90)
# Out:
# <Axes: title={'center': 'Purchase by City Category'}>

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar',title='Purchase by saty in Current City Years')
# Out:
# <Axes: title={'center': 'Purchase by saty in Current City Years'}, xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind='bar',title='Purchase by saty in Current City Years')
# Out:
# <Axes: title={'center': 'Purchase by saty in Current City Years'}, xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar',title='Purchase by Occupation')
# Out:
# <Axes: title={'center': 'Purchase by Occupation'}, xlabel='Occupation'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='pie',figsize=(8,8),autopct="%0.1f%%",title='Purchase by Occupation')
# Out:
# <Axes: title={'center': 'Purchase by Occupation'}>

# %%
df.groupby('Occupation')['Purchase'].mean().sort_values().plot(kind='bar',title='Purchase by Occupation')
# Out:
# <Axes: title={'center': 'Purchase by Occupation'}, xlabel='Occupation'>

# %%
df['Occupation']=df['Occupation'].astype(str)
df['Marital_Status']=df['Marital_Status'].astype(str)
sns.countplot(x='Occupation',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df['Occupation']=df['Occupation'].astype(str)
df['Gender']=df['Gender'].astype(str)
sns.countplot(x='Occupation',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar',figsize=(8,6))
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].mean().sort_values().plot(kind='bar',figsize=(8,6))
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values().plot(kind='bar',figsize=(8,6))
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind='bar',figsize=(8,6))
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values().plot(kind='bar',figsize=(8,6))
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID').size().nlargest(10).sort_values().plot(kind='bar',figsize=(8,6))
# Out:
# <Axes: xlabel='Product_ID'>

# %%
#sns.set(rc={'figure.figsize':(8,6)})
sns.countplot(x='Product_Category_1',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x='Product_Category_1',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
l=[]
for i in range(len(df)):
    l.append(df['Gender'][i]+"_"+str(df['Marital_Status'][i]))
    
df['Marital_Gender'] = l

# %%
sns.set_style("white")
sns.countplot(x=df['Marital_Gender'])
# Out:
# <Axes: xlabel='Marital_Gender', ylabel='count'>

# %%
sns.set_style("white")
sns.countplot(x=df['Age'],hue=df['Marital_Gender'],data=df,palette='colorblind')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x=df['Product_Category_1'],hue=df['Marital_Gender'],data=df,palette='colorblind')
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase', 'MaritalGender', 'Marital_Gender'],
#       dtype='object')

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['Marital_Gender'],data=df,palette='colorblind')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Age').size()
